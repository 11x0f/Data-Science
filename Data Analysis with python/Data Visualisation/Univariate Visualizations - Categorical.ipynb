# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %% [markdown]
# # CATEGORICAL

# %% [markdown]
# ### BAR GRAPH

# %%
sns.countplot(data=df, x="neighbourhood_group")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(data=df, x="room_type")
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
sns.countplot(data=df, x="neighbourhood_group", hue="room_type")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# ### PIE CHART

# %%
df["room_type"].value_counts().plot(kind = "pie", autopct="%0.3f")
# Out:
# <Axes: ylabel='room_type'>

# %%
df["neighbourhood_group"].value_counts().plot(kind="pie", autopct="%0.2f")
# Out:
# <Axes: ylabel='neighbourhood_group'>

# %% [markdown]
# # NEW DATASET FROM SEABORN

# %%
df2= sns.load_dataset("titanic")

# %%
df2.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
sns.countplot(data=df2, x="survived", hue="sex")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
df2["class"].value_counts().plot(kind="pie", autopct="%0.2f")
# Out:
# <Axes: ylabel='class'>
